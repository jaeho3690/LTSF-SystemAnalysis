# %%
import os 
import glob 
import numpy as np
import pandas as pd 

# set max column 
pd.set_option('display.max_columns', 500)

# %%
### PLEASE CHANGE THIS
YOUR_NAME = 'JAEHO'

# %%
all_files = glob.glob(f"../outputs/*/*/run_*.csv")
all_files
# Out:
# ['../outputs/ETTh1/EXP1002/run_exp1002_seed3_Informer.csv',
#  '../outputs/ETTh1/EXP1004/run_exp1004_seed2_Informer.csv',
#  '../outputs/ETTh1/EXP1001/run_exp1001_seed2_Informer.csv',
#  '../outputs/ETTh1/EXP1003/run_exp1003_seed1_Informer.csv',
#  '../outputs/ETTh1/EXP1000/run_exp1000_seed1_Informer.csv']

# %%
pd_files = []
for file in all_files: 
    pd_files.append(pd.read_csv(file))
all_df = pd.concat(pd_files, axis=0, ignore_index=True)

# %%
all_df['PERSON'] = YOUR_NAME

# %%
all_df
# Out:
#    prior_to_model_building  after_model_building  pytorch_total_params  \
# 0                      0.0                   0.0              11328007
# 1                      0.0                   0.0              11328007
# 2                      0.0                   0.0              11328007
# 3                      0.0                   0.0              11328007
# 4                      0.0                   0.0              11328007
#
#    before_first_batch_0  after_first_batch_0  before_model_forward_0  \
# 0             64.545898            64.545898               65.313477
# 1             65.512695            65.512695               68.583008
# 2             64.545898            64.545898               65.313477
# 3             65.512695            65.512695               68.583008
# 4             64.545898            64.545898               65.313477
#
#    after_model_forward_0  before_loss_0  after_loss_0  before_first_batch_3  \
# 0             377.154785     377.154785    377.237305            196.564453
# 1            1232.059082    1232.059082   1232.387695            197.406738
# 2             377.154785     377.154785    377.237305            196.564453
# 3            1232.059082    1232.059082   1232.387695            197.406250
# 4             377.154785     377.154785    377.237305            196.564453
#
#    after_first_batch_3  before_model_forward_3  after_model_forward_3  \
# 0           196.564453              197.332031             513.360840
# 1           197.406738              200.477051            1365.617188
# 2           196.564453              197.332031             513.360840
# 3           197.406250              200.476562            1365.616699
# 4           196.564453              197.332031             513.360840
#
#    before_loss_3  after_loss_3           device_name  device_total_memory  \
# 0     513.360840    513.443359  Tesla V100-PCIE-32GB            34.089927
# 1    1365.617188   1365.945801  Tesla V100-PCIE-32GB            34.089927
# 2     513.360840    513.443359  Tesla V100-PCIE-32GB            34.089927
# 3    1365.616699   1365.945312  Tesla V100-PCIE-32GB            34.089927
# 4     513.360840    513.443359  Tesla V100-PCIE-32GB            34.089927
#
#    num_threads  model_size_mb  max_memory_mb python_ver   pytorch_ver  \
# 0           16      65.825022     578.991104     3.9.13  1.10.0+cu111
# 1           16      65.825022    1575.985152     3.9.13  1.10.0+cu111
# 2           16      65.825022     578.991104     3.9.13  1.10.0+cu111
# 3           16      65.825022    1575.985152     3.9.13  1.10.0+cu111
# 4           16      65.825022     578.991104     3.9.13  1.10.0+cu111
#
#   pytorch_lightning_ver data_name model_name  seq_len  label_len  pred_len  \
# 0                 1.6.5     ETTh1   Informer       96         48        96
# 1                 1.6.5     ETTh1   Informer       96         48        96
# 2                 1.6.5     ETTh1   Informer       96         48        96
# 3                 1.6.5     ETTh1   Informer       96         48        96
# 4                 1.6.5     ETTh1   Informer       96         48        96
#
#   features  exp_num  exp_seed  use_amp  cpu_thread  num_workers  batch_size  \
# 0        M     1002         3     True          16            4          32
# 1        M     1004         2     True          16            4         128
# 2        M     1001         2     True          16            4          32
# 3        M     1003         1     True          16            4         128
# 4        M     1000         1     True          16            4          32
#
#    test_loss       mae       mse  train_epoch  train_batch  secs/batch  \
# 0   1.417681  0.901446  1.417599            8          264    0.013489
# 1   1.412635  0.927544  1.412551            3           66    0.029969
# 2   1.383538  0.915603  1.383445            9          264    0.013693
# 3   1.365930  0.892472  1.365844            5           66    0.029962
# 4   1.352916  0.885748  1.352818           11          264    0.013939
#
#    secs/epoch                                        model_hpams PERSON
# 0    3.561213  {'model_name': 'Informer', 'embed_type': 0, 'e...  JAEHO
# 1    1.977967  {'model_name': 'Informer', 'embed_type': 0, 'e...  JAEHO
# 2    3.614898  {'model_name': 'Informer', 'embed_type': 0, 'e...  JAEHO
# 3    1.977462  {'model_name': 'Informer', 'embed_type': 0, 'e...  JAEHO
# 4    3.679952  {'model_name': 'Informer', 'embed_type': 0, 'e...  JAEHO

# %%
all_df.groupby(['device_name','data_name','model_name','seq_len','pred_len'])[['secs/batch', 'secs/epoch']].describe()
# Out:
#                                                            secs/batch  \
#                                                                 count
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96              2.0
#
#                                                                       \
#                                                                 mean
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013816
#
#                                                                       \
#                                                                  std
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.000174
#
#                                                                       \
#                                                                  min
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013693
#
#                                                                       \
#                                                                  25%
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013754
#
#                                                                       \
#                                                                  50%
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013816
#
#                                                                       \
#                                                                  75%
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013878
#
#                                                                       \
#                                                                  max
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.013939
#
#                                                            secs/epoch  \
#                                                                 count
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96              2.0
#
#                                                                       \
#                                                                 mean
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        3.647425
#
#                                                                       \
#                                                                  std
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        0.046001
#
#                                                                       \
#                                                                  min
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        3.614898
#
#                                                                       \
#                                                                  25%
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        3.631161
#
#                                                                       \
#                                                                  50%
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        3.647425
#
#
#                                                                  75%       max
# device_name          data_name model_name seq_len pred_len
# Tesla V100-PCIE-32GB ETTh1     Informer   96      96        3.663688  3.679952

# %%
all_df.columns
# Out:
# Index(['prior_to_model_building', 'after_model_building',
#        'pytorch_total_params', 'before_first_batch_0', 'after_first_batch_0',
#        'before_model_forward_0', 'after_model_forward_0', 'before_loss_0',
#        'after_loss_0', 'before_first_batch_3', 'after_first_batch_3',
#        'before_model_forward_3', 'after_model_forward_3', 'before_loss_3',
#        'after_loss_3', 'device_name', 'device_total_memory', 'num_threads',
#        'model_size_mb', 'max_memory_mb', 'python_ver', 'pytorch_ver',
#        'pytorch_lightning_ver', 'data_name', 'model_name', 'seq_len',
#        'label_len', 'pred_len', 'features', 'exp_num', 'exp_seed', 'use_amp',
#        'cpu_thread', 'num_workers', 'batch_size', 'test_loss', 'mae', 'mse',
#        'train_epoch', 'train_batch', 'secs/batch', 'secs/epoch',
#        'model_hpams'],
#       dtype='object')
